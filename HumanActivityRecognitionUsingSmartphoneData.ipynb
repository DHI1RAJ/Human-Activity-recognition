# %% [markdown]
# # Human Activity Recognition

# %% [markdown]
# ## Description
# These days Smartphones have become an integral part of our life. We cannot assume our life without a mobile phone. Since, the advent of Smartphones, a revolution has been created in the mobile communication industry. Smartphones are not just restricted for calling these days. Infact, they are more often used for entertainment purpose.<br><br>
# Smartphone manufacturing companies load Smartphones with various sensors to enhance the user experinece. Two of the such sensors are <b>Accelerometer</b> and <b>Gyroscope</b>. <b>Accelerometer</b> measures acceleration while <b>Gyroscope</b> measures angular velocity.<br><br>
# Here, we will try to use the data provided by accelerometer and gyroscope of Smartphone to classify the activity which a Smartphone user is performing.

# %% [markdown]
# ## Why this is Useful?
# These days, in addition to Smartphones, we are also using Smart-Watches like Fitbit or Apple-Watch, which help us to track our health. They monitor our each activity throughout the day check how many calories we have burnt. How many hours have we slept. However, in addition to Accelerometer and Gyroscope, they also use Heart-Rate data to monitor our activity. Since, we only have Smartphone data so just by using  Accelerometer and Gyroscope data we will monitor the activity of a person. This software can then be converted into an App which can be downloaded in Smartphone. Hence, a person who has Smartphone can monitor his/her health using this App

# %% [markdown]
# ## Information about Data
# ### How Data is recorded
#  The experiments have been carried out with a group of 30 volunteers within an age bracket of 19-48 years. Each person performed six activities <b>(WALKING, WALKING-UPSTAIRS, WALKING-DOWNSTAIRS, SITTING-DOWN, STANDING-UP, LAYING-DOWN)</b> wearing a smartphone (Samsung Galaxy S II) on the waist. Using its embedded accelerometer and gyroscope, we captured 3-axial linear acceleration and 3-axial angular velocity at a constant rate of 50Hz.The obtained dataset has been randomly partitioned into two sets, where 70% of the volunteers was selected for generating the training data and 30% the test data.
# 5.2. Features
# 1. These sensor signals are pre-processed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. i.e., each window has 128 readings. A 128 size vector is created from each window.
# 2. From Each window or to be more precise, from each 128 readings domain experts from signal processing have engineered feature vector of size 561 by calculating variables from the time and frequency domain. In our dataset, each data-point represents a window with different readings.
# 3. The acceleration signal was separated into Body and Gravity acceleration signals(tBodyAcc-XYZ and tGravityAcc-XYZ) using some low pass filter with corner frequency of 0.3Hz.
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtain jerk signals (tBodyAccJerk-XYZ and tBodyGyroJerk-XYZ).
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like tBodyAccMag, tGravityAccMag, tBodyAccJerkMag, tBodyGyroMag and tBodyGyroJerkMag.
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labelled with prefix 'f' just like original signals with prefix 't'. These signals are labelled as fBodyAcc-XYZ, fBodyGyroMag etc.<br>
#
# These are the signals that we got so far.
#
# * tBodyAcc-XYZ
# * tGravityAcc-XYZ
# * tBodyAccJerk-XYZ
# * tBodyGyro-XYZ
# * tBodyGyroJerk-XYZ
# * tBodyAccMag
# * tGravityAccMag
# * tBodyAccJerkMag
# * tBodyGyroMag
# * tBodyGyroJerkMag
# * fBodyAcc-XYZ
# * fBodyAccJerk-XYZ
# * fBodyGyro-XYZ
# * fBodyAccMag
# * fBodyAccJerkMag
# * fBodyGyroMag
# * fBodyGyroJerkMag<br><br>
#
# 7. We can estimate some set of variables from the above signals. i.e., We will estimate the following properties on each and every signal that we recorded so far.
# * mean(): Mean value
# * std(): Standard deviation
# * mad(): Median absolute deviation
# * max(): Largest value in array
# * min(): Smallest value in array
# * sma(): Signal magnitude area
# * energy(): Energy measure. Sum of the squares divided by the number of values.
# * iqr(): Inter-quartile range
# * entropy(): Signal entropy
# * arCoeff(): Auto-regression coefficients with Burg order equal to 4
# * correlation(): correlation coefficient between two signals
# * maxInds(): index of the frequency component with largest magnitude
# * meanFreq(): Weighted average of the frequency components to obtain a mean frequency
# * skewness(): skewness of the frequency domain signal
# * kurtosis(): kurtosis of the frequency domain signal
# * bandsEnergy(): Energy of a frequency interval within the 64 bins of the FFT of each window.
# * angle(): Angle between to vectors.<br><br>
#
# 8. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable.
# * gravityMean
# * tBodyAccMean
# * tBodyAccJerkMean
# * tBodyGyroMean
# * tBodyGyroJerkMean

# %% [markdown]
# ## Data Source
# Data is downloaded from following source:<br>
# https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones

# %% [markdown]
# ## Quick Overview of Dataset
# Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.<br><br>
# <b>These activites are encoded as follows:<br>
# WALKING-- 1<br>
# WALKING_UPSTAIRS-- 2<br>
# WALKING_DOWNSTAIRS-- 3<br>
# SITTING-- 4<br>
# STANDING-- 5<br>
# LYING-- 6<br>
# </b>
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings, which has x, y and z components each.
# * Gyroscope readings are the measure of angular velocities which has x, y and z components.
# * Jerk signals are calculated for Body-Acceleration readings.
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, energy-bands, entropy etc., are calculated for each window.
# * Extra features are calculated by taking the average of signals in a single window sample. These are used on the angle() variable.
# * Finally, we got feature vector of 561 features and these features are given in the dataset.
# * Each window of readings is a data-point of 561 features.

# %% [markdown]
# ## Problem Statement
# <br> By using either human engineered 561 feature data or raw features of 128 reading, our goal is to predict one of the six activities that a Smartphone user is performing at that 2.56 Seconds time window.</b>

# %% [markdown]
# ## ML Problem Formulation
# All of the Accelerometer and Gyroscope are tri-axial, means that they measure acceleration and angular-velocity respectively in all the three axis namely X-axis, Y-axis and Z-axis. So, we have in total six time-series data. Given this six time-series data, we want to predict six activities namely <b>Walking</b> or <b>Walking-Upstairs</b> or <b>Walking-Downstairs</b> or <b>Lying-Down</b> or <b>Standing-Up</b> or <b>Sitting-Down</b>.<br><br>
# <b>At the outset, this is a multi-class classification problem.</b>

# %% [markdown]
# ## Performance Metric
# 1. We will use Accuracy as one of the metric.
# 2. We will also use Confusion-Matrix to check that in which two activities our model is confused and predicting incorrect activity. For example, between Standing-Up and Sitting-Down. Between Walking-Upstairs and Walking-Downstairs.

# %% [markdown]
# ## Data-Points Distribution
# * 30 test-subjects data is randomly split to 70%(21) train and 30%(7) test data.
# * Each data-point corresponds one of the 6 Activities.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from datetime import datetime
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import warnings
warnings.simplefilter("ignore")

# %%
features = list()
with open("../Data/Features.txt") as f:
    for line in f:
        features.append(line.split()[1])

# %%
train_df = pd.read_csv("../Data/train/X_train.txt", delim_whitespace = True, names = features)

train_df["subject_id"] = pd.read_csv("../Data/train/subject_train.txt", header = None, squeeze = True) #squeeze = True will 
#return data in pandas series format

train_df["activity"] = pd.read_csv("../Data/train/y_train.txt", header = None, squeeze = True)

activity = pd.read_csv("../Data/train/y_train.txt", header = None, squeeze = True)

#mapping activity to activity name
label_name = activity.map({1: "WALKING", 2:"WALKING_UPSTAIRS", 3:"WALKING_DOWNSTAIRS", 4:"SITTING", 5:"STANDING", 6:"LYING"})

train_df["activity_name"] = label_name
                                                                                                                                                                                                                
train_df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# 1            -0.998245         -0.975300         -0.960322         -0.998807
# 2            -0.995380         -0.967187         -0.978944         -0.996520
# 3            -0.996091         -0.983403         -0.990675         -0.997099
# 4            -0.998139         -0.980817         -0.990482         -0.998321
# ...                ...               ...               ...               ...
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.983185         -0.923527         -0.934724  ...
# 1            -0.974914         -0.957686         -0.943068  ...
# 2            -0.963668         -0.977469         -0.938692  ...
# 3            -0.982750         -0.989302         -0.938692  ...
# 4            -0.979672         -0.990441         -0.942469  ...
# ...                ...               ...               ...  ...
# 7347          0.043616          0.060410          0.210795  ...
# 7348         -0.029456          0.080585          0.117440  ...
# 7349         -0.098913          0.332584          0.043999  ...
# 7350         -0.068200          0.319473          0.101702  ...
# 7351         -0.038678          0.229430          0.269013  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                       -0.112754                              0.030400
# 1                        0.053477                             -0.007435
# 2                       -0.118559                              0.177899
# 3                       -0.036788                             -0.012892
# 4                        0.123320                              0.122542
# ...                           ...                                   ...
# 7347                    -0.190437                              0.829718
# 7348                     0.064907                              0.875679
# 7349                     0.052806                             -0.266724
# 7350                    -0.101360                              0.700740
# 7351                    -0.280088                             -0.007739
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                            -0.464761                             -0.018446
# 1                            -0.732626                              0.703511
# 2                             0.100699                              0.808529
# 3                             0.640011                             -0.485366
# 4                             0.693578                             -0.615971
# ...                                ...                                   ...
# 7347                          0.206972                             -0.425619
# 7348                         -0.879033                              0.400219
# 7349                          0.864404                              0.701169
# 7350                          0.936674                             -0.589479
# 7351                         -0.056088                             -0.616956
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0                -0.841247              0.179941             -0.058627
# 1                -0.844788              0.180289             -0.054317
# 2                -0.848933              0.180637             -0.049118
# 3                -0.848649              0.181935             -0.047663
# 4                -0.847865              0.185151             -0.043892
# ...                    ...                   ...                   ...
# 7347             -0.791883              0.238604              0.049819
# 7348             -0.771840              0.252676              0.050053
# 7349             -0.779133              0.249145              0.040811
# 7350             -0.785181              0.246432              0.025339
# 7351             -0.783267              0.246809              0.036695
#
#       subject_id  activity     activity_name
# 0              1         5          STANDING
# 1              1         5          STANDING
# 2              1         5          STANDING
# 3              1         5          STANDING
# 4              1         5          STANDING
# ...          ...       ...               ...
# 7347          30         2  WALKING_UPSTAIRS
# 7348          30         2  WALKING_UPSTAIRS
# 7349          30         2  WALKING_UPSTAIRS
# 7350          30         2  WALKING_UPSTAIRS
# 7351          30         2  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]

# %%
print("Size of Train data = {}".format(train_df.shape))
# Out:
# Size of Train data = (7352, 564)

# %%
test_df = pd.read_csv("../Data/test/X_test.txt", delim_whitespace = True, names = features)
test_df["subject_id"] = pd.read_csv("../Data/test/subject_test.txt", header = None, squeeze = True) #squeeze = True will 
#return data in pandas series format

test_df["activity"] = pd.read_csv("../Data/test/y_test.txt", header = None, squeeze = True)

activity = pd.read_csv("../Data/test/y_test.txt", header = None, squeeze = True)

#mapping activity to activity name
label_name = activity.map({1: "WALKING", 2:"WALKING_UPSTAIRS", 3:"WALKING_DOWNSTAIRS", 4:"SITTING", 5:"STANDING", 6:"LYING"})

test_df["activity_name"] = label_name

test_df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# 1            -0.975415         -0.967458         -0.944958         -0.986799
# 2            -0.993819         -0.969926         -0.962748         -0.994403
# 3            -0.994743         -0.973268         -0.967091         -0.995274
# 4            -0.993852         -0.967445         -0.978295         -0.994111
# ...                ...               ...               ...               ...
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.925249         -0.674302         -0.894088  ...
# 1            -0.968401         -0.945823         -0.894088  ...
# 2            -0.970735         -0.963483         -0.939260  ...
# 3            -0.974471         -0.968897         -0.938610  ...
# 4            -0.965953         -0.977346         -0.938610  ...
# ...                ...               ...               ...  ...
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                        0.006462                              0.162920
# 1                       -0.083495                              0.017500
# 2                       -0.034956                              0.202302
# 3                       -0.017067                              0.154438
# 4                       -0.002223                             -0.040046
# ...                           ...                                   ...
# 2942                    -0.337422                              0.346295
# 2943                    -0.736701                             -0.372889
# 2944                    -0.181560                              0.088574
# 2945                     0.444558                             -0.819188
# 2946                     0.598808                             -0.287951
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                            -0.825886                              0.271151
# 1                            -0.434375                              0.920593
# 2                             0.064103                              0.145068
# 3                             0.340134                              0.296407
# 4                             0.736715                             -0.118545
# ...                                ...                                   ...
# 2942                          0.884904                             -0.698885
# 2943                         -0.657421                              0.322549
# 2944                          0.696663                              0.363139
# 2945                          0.929294                             -0.008398
# 2946                          0.876030                             -0.024965
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0                -0.720009              0.276801             -0.057978
# 1                -0.698091              0.281343             -0.083898
# 2                -0.702771              0.280083             -0.079346
# 3                -0.698954              0.284114             -0.077108
# 4                -0.692245              0.290722             -0.073857
# ...                    ...                   ...                   ...
# 2942             -0.651732              0.274627              0.184784
# 2943             -0.655181              0.273578              0.182412
# 2944             -0.655357              0.274479              0.181184
# 2945             -0.659719              0.264782              0.187563
# 2946             -0.660080              0.263936              0.188103
#
#       subject_id  activity     activity_name
# 0              2         5          STANDING
# 1              2         5          STANDING
# 2              2         5          STANDING
# 3              2         5          STANDING
# 4              2         5          STANDING
# ...          ...       ...               ...
# 2942          24         2  WALKING_UPSTAIRS
# 2943          24         2  WALKING_UPSTAIRS
# 2944          24         2  WALKING_UPSTAIRS
# 2945          24         2  WALKING_UPSTAIRS
# 2946          24         2  WALKING_UPSTAIRS
#
# [2947 rows x 564 columns]

# %%
print("Size of Test data = {}".format(test_df.shape))
# Out:
# Size of Test data = (2947, 564)

# %% [markdown]
# ## 2. Data Cleaning

# %%
# Checking for nan values
print("Number of NaN values in train data is "+str(train_df.isnull().sum().sum()))
print("Number of NaN values in test data is "+str(test_df.isnull().sum().sum()))
# Out:
# Number of NaN values in train data is 0
# Number of NaN values in test data is 0

# %%
# Checking for duplicate values
print("Number of duplicate values in train data is "+str(sum(train_df.duplicated())))
print("Number of duplicate values in test data is "+str(sum(test_df.duplicated())))
# Out:
# Number of duplicate values in train data is 0
# Number of duplicate values in test data is 0

# %% [markdown]
# ## 3. Checking for imbalance in data

# %%
fig = plt.figure(figsize = (12, 8))
ax = fig.add_axes([0,0,1,1])
ax.set_title("Activity by each test subject", fontsize = 15)
plt.tick_params(labelsize = 15)
sns.countplot(x = "subject_id", hue = "activity_name", data = train_df)
plt.xlabel("Subject ID", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.show()

# %%
fig = plt.figure(figsize = (10, 6))
ax = fig.add_axes([0,0,1,1])
ax.set_title("Count of each activity", fontsize = 15)
sns.countplot(x = "activity_name", data = train_df)
for i in ax.patches:
    ax.text(x = i.get_x() + 0.2, y = i.get_height()+10, s = str(i.get_height()), fontsize = 20, color = "grey")
plt.xlabel("")
plt.ylabel("Count", fontsize = 15)
plt.tick_params(labelsize = 13)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# # <b>Observation</b><br>
# From the above two plots, we can infer that our classes are almost balanced.

# %% [markdown]
# ## 4. Changing Feature Name

# %%
columns = train_df.columns

# %%
columns = columns.str.replace("[()]", '') 
columns = columns.str.replace("-", '')
columns = columns.str.replace(",", '')
#here, columns is of type pandas index. By writing "columns.str" we have changed its type to 
#pandas string. Pandas string has method called replace which we have used here.

train_df.columns = columns
test_df.columns = columns

# %%
train_df.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject_id', 'activity', 'activity_name'],
#       dtype='object', length=564)

# %%
train_df
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1          0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2          0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3          0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4          0.276629      -0.016570      -0.115362     -0.998139     -0.980817
# ...             ...            ...            ...           ...           ...
# 7347       0.299665      -0.057193      -0.181233     -0.195387      0.039905
# 7348       0.273853      -0.007749      -0.147468     -0.235309      0.004816
# 7349       0.273387      -0.017011      -0.045022     -0.218218     -0.103822
# 7350       0.289654      -0.018843      -0.158281     -0.219139     -0.111412
# 7351       0.351503      -0.012423      -0.203867     -0.269270     -0.087212
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.913526     -0.995112     -0.983185     -0.923527     -0.934724
# 1        -0.960322     -0.998807     -0.974914     -0.957686     -0.943068
# 2        -0.978944     -0.996520     -0.963668     -0.977469     -0.938692
# 3        -0.990675     -0.997099     -0.982750     -0.989302     -0.938692
# 4        -0.990482     -0.998321     -0.979672     -0.990441     -0.942469
# ...            ...           ...           ...           ...           ...
# 7347      0.077078     -0.282301      0.043616      0.060410      0.210795
# 7348      0.059280     -0.322552     -0.029456      0.080585      0.117440
# 7349      0.274533     -0.304515     -0.098913      0.332584      0.043999
# 7350      0.268893     -0.310487     -0.068200      0.319473      0.101702
# 7351      0.177404     -0.377404     -0.038678      0.229430      0.269013
#
#       ...  angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0     ...                 -0.112754                          0.030400
# 1     ...                  0.053477                         -0.007435
# 2     ...                 -0.118559                          0.177899
# 3     ...                 -0.036788                         -0.012892
# 4     ...                  0.123320                          0.122542
# ...   ...                       ...                               ...
# 7347  ...                 -0.190437                          0.829718
# 7348  ...                  0.064907                          0.875679
# 7349  ...                  0.052806                         -0.266724
# 7350  ...                 -0.101360                          0.700740
# 7351  ...                 -0.280088                         -0.007739
#
#       angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                         -0.464761                          -0.018446
# 1                         -0.732626                           0.703511
# 2                          0.100699                           0.808529
# 3                          0.640011                          -0.485366
# 4                          0.693578                          -0.615971
# ...                             ...                                ...
# 7347                       0.206972                          -0.425619
# 7348                      -0.879033                           0.400219
# 7349                       0.864404                           0.701169
# 7350                       0.936674                          -0.589479
# 7351                      -0.056088                          -0.616956
#
#       angleXgravityMean  angleYgravityMean  angleZgravityMean  subject_id  \
# 0             -0.841247           0.179941          -0.058627           1
# 1             -0.844788           0.180289          -0.054317           1
# 2             -0.848933           0.180637          -0.049118           1
# 3             -0.848649           0.181935          -0.047663           1
# 4             -0.847865           0.185151          -0.043892           1
# ...                 ...                ...                ...         ...
# 7347          -0.791883           0.238604           0.049819          30
# 7348          -0.771840           0.252676           0.050053          30
# 7349          -0.779133           0.249145           0.040811          30
# 7350          -0.785181           0.246432           0.025339          30
# 7351          -0.783267           0.246809           0.036695          30
#
#       activity     activity_name
# 0            5          STANDING
# 1            5          STANDING
# 2            5          STANDING
# 3            5          STANDING
# 4            5          STANDING
# ...        ...               ...
# 7347         2  WALKING_UPSTAIRS
# 7348         2  WALKING_UPSTAIRS
# 7349         2  WALKING_UPSTAIRS
# 7350         2  WALKING_UPSTAIRS
# 7351         2  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]

# %%
test_df
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1          0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2          0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3          0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4          0.274833      -0.027848      -0.129527     -0.993852     -0.967445
# ...             ...            ...            ...           ...           ...
# 2942       0.310155      -0.053391      -0.099109     -0.287866     -0.140589
# 2943       0.363385      -0.039214      -0.105915     -0.305388      0.028148
# 2944       0.349966       0.030077      -0.115788     -0.329638     -0.042143
# 2945       0.237594       0.018467      -0.096499     -0.323114     -0.229775
# 2946       0.153627      -0.018437      -0.137018     -0.330046     -0.195253
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.667683     -0.952501     -0.925249     -0.674302     -0.894088
# 1        -0.944958     -0.986799     -0.968401     -0.945823     -0.894088
# 2        -0.962748     -0.994403     -0.970735     -0.963483     -0.939260
# 3        -0.967091     -0.995274     -0.974471     -0.968897     -0.938610
# 4        -0.978295     -0.994111     -0.965953     -0.977346     -0.938610
# ...            ...           ...           ...           ...           ...
# 2942     -0.215088     -0.356083     -0.148775     -0.232057      0.185361
# 2943     -0.196373     -0.373540     -0.030036     -0.270237      0.185361
# 2944     -0.250181     -0.388017     -0.133257     -0.347029      0.007471
# 2945     -0.207574     -0.392380     -0.279610     -0.289477      0.007471
# 2946     -0.164339     -0.430974     -0.218295     -0.229933     -0.111527
#
#       ...  angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0     ...                  0.006462                          0.162920
# 1     ...                 -0.083495                          0.017500
# 2     ...                 -0.034956                          0.202302
# 3     ...                 -0.017067                          0.154438
# 4     ...                 -0.002223                         -0.040046
# ...   ...                       ...                               ...
# 2942  ...                 -0.337422                          0.346295
# 2943  ...                 -0.736701                         -0.372889
# 2944  ...                 -0.181560                          0.088574
# 2945  ...                  0.444558                         -0.819188
# 2946  ...                  0.598808                         -0.287951
#
#       angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                         -0.825886                           0.271151
# 1                         -0.434375                           0.920593
# 2                          0.064103                           0.145068
# 3                          0.340134                           0.296407
# 4                          0.736715                          -0.118545
# ...                             ...                                ...
# 2942                       0.884904                          -0.698885
# 2943                      -0.657421                           0.322549
# 2944                       0.696663                           0.363139
# 2945                       0.929294                          -0.008398
# 2946                       0.876030                          -0.024965
#
#       angleXgravityMean  angleYgravityMean  angleZgravityMean  subject_id  \
# 0             -0.720009           0.276801          -0.057978           2
# 1             -0.698091           0.281343          -0.083898           2
# 2             -0.702771           0.280083          -0.079346           2
# 3             -0.698954           0.284114          -0.077108           2
# 4             -0.692245           0.290722          -0.073857           2
# ...                 ...                ...                ...         ...
# 2942          -0.651732           0.274627           0.184784          24
# 2943          -0.655181           0.273578           0.182412          24
# 2944          -0.655357           0.274479           0.181184          24
# 2945          -0.659719           0.264782           0.187563          24
# 2946          -0.660080           0.263936           0.188103          24
#
#       activity     activity_name
# 0            5          STANDING
# 1            5          STANDING
# 2            5          STANDING
# 3            5          STANDING
# 4            5          STANDING
# ...        ...               ...
# 2942         2  WALKING_UPSTAIRS
# 2943         2  WALKING_UPSTAIRS
# 2944         2  WALKING_UPSTAIRS
# 2945         2  WALKING_UPSTAIRS
# 2946         2  WALKING_UPSTAIRS
#
# [2947 rows x 564 columns]

# %% [markdown]
# ## 5. Saving Dataframe for future use

# %%
train_df.to_csv("../Data/train/train_df.csv", index = False)
test_df.to_csv("../Data/test/test_df.csv", index = False)

# %%
train_df = pd.read_csv("../Data/train/train_df.csv")
test_df = pd.read_csv("../Data/test/test_df.csv")

# %% [markdown]
# ## 6. Exploratory Data Analysis

# %% [markdown]
# <b>Feature information from domain knowledge</b>
# 1. <b>Static:</b> We have three types static features where test subject is in rest:
#     * Sitting
#     * Standing
#     * Lying
# 2. <b>Dynamic:</b> We have three types of dynamic features where test subject is in motion:
#     * Walking
#     * Walking_Downstairs
#     * Walking_Upstairs

# %% [markdown]
# ### Magnitude of Body Accelerator Mean

# %%
facetgrid = sns.FacetGrid(data = train_df, hue = "activity_name", size = 8)
facetgrid.map(sns.distplot, "tBodyAccMagmean",hist=False).add_legend()
plt.annotate('Dynamic Activities(Walking, Walking_Upstairs, Walking_Downstairs)', xy=(0.1, 3), xytext=(-0.5, 6),
            arrowprops=dict(facecolor='orange', width = 7, headlength = 13), size = 12, color = "#232b2b")
plt.annotate('Static Activities(Sitting, Standing, Lying)', xy=(-0.90, 10), xytext=(-0.7, 15),
            arrowprops=dict(facecolor='orange', width = 7, headlength = 15), size = 12, color = "#232b2b")
plt.show()

# %%
#let's plot "tBodyAccMagmean" for both static and dynamic activites separately to analysis them in more detail
df_standing = train_df[train_df["activity_name"] == "STANDING"]
df_sitting = train_df[train_df["activity_name"] == "SITTING"]
df_lying = train_df[train_df["activity_name"] == "LYING"]
df_walking = train_df[train_df["activity_name"] == "WALKING"]
df_walking_upstairs = train_df[train_df["activity_name"] == "WALKING_UPSTAIRS"]
df_walking_downstairs = train_df[train_df["activity_name"] == "WALKING_DOWNSTAIRS"]

fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (14, 7))

axes[0].set_title("Static Activities for tBodyAccMagmean--Zoomed In")
sns.distplot(df_standing["tBodyAccMagmean"], hist = False, label = "STANDING", ax = axes[0])
sns.distplot(df_sitting["tBodyAccMagmean"], hist = False, label = "SITTING", ax = axes[0])
sns.distplot(df_lying["tBodyAccMagmean"], hist = False, label = "LYING", ax = axes[0])
axes[0].legend(fontsize = 15)
axes[0].annotate('Static Activities', xy=(-0.90, 10), xytext=(-0.7, 15),
            arrowprops=dict(facecolor='orange', width = 7, headlength = 13), size = 15, color = "#232b2b")

axes[1].set_title("Dynamic Activities for tBodyAccMagmean--Zoomed In")
sns.distplot(df_walking["tBodyAccMagmean"], hist = False, label = "WALKING", ax = axes[1])
sns.distplot(df_walking_upstairs["tBodyAccMagmean"], hist = False, label = "WALKING_UPSTAIRS", ax = axes[1])
sns.distplot(df_walking_downstairs["tBodyAccMagmean"], hist = False, label = "WALKING_DOWNSTAIRS", ax = axes[1])
axes[1].legend(fontsize = 15)
axes[1].annotate('Dynamic Activities', xy=(0.37, 1.5), xytext=(0.60, 2.2),
            arrowprops=dict(facecolor='orange', width = 7, headlength = 13), size = 15, color = "#232b2b")

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Observation</b><br>
# From above two plots we can clearly observe that how well "tBodyAccMagmean"--which is the magnitude of the mean of body acceleration in time-domain meaured by accelerometer--is able to separate static activity from dynamic activity.

# %% [markdown]
# ### Analysis Of Accelerator Body Mean Using Boxplot

# %%
plt.figure(figsize = (15, 7))
sns.boxplot(x = "activity_name", y = "tBodyAccMagmean", showfliers = False, data = train_df)
plt.axhline(y = -0.65, linestyle = "--")
plt.axhline(y = 0, linestyle = "--")
plt.title("Box plot of tBodyAccMagmean", fontsize = 15)
plt.ylabel("Accelerator Body Mean", fontsize = 15)
plt.xlabel("Activity Name", fontsize = 15)
plt.xlabel("")
plt.tick_params(labelsize = 15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# <b>Observations:</b><br>
# * If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# * If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# * If tAccMean > 0.0 then the Activity is WalkingDownstairs.

# %% [markdown]
# ### Analysis Of Accelerator Gravity Mean Using Boxplot

# %%
plt.figure(figsize = (15, 7))
sns.boxplot(x = "activity_name", y = "angleXgravityMean", showfliers = True, data = train_df)
plt.axhline(y = 0, linestyle = "--")
plt.title("Box plot of tGravityAccMagmean", fontsize = 15)
plt.ylabel("Accelerator Gravity Mean", fontsize = 15)
plt.xlabel("")
plt.tick_params(labelsize = 15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# <b>Observation</b><br>
# * If Acc Gravity Mean > 0, we can infer that the activity will most likely be <b>Lying</b>.
# * If Acc Gravity Mean < 0, we can infer that the activity can be anything but not <b>Lying</b>.

# %% [markdown]
# ## 7. Applying T-SNE on Data

# %%
def plt_tsne(perplexity, train_df):
    data = train_df.drop(["subject_id", "activity", "activity_name"], axis = 1)
    data_label = train_df["activity_name"]
    applying_tsne = TSNE(n_components = 2, perplexity = perplexity, n_iter = 1000, verbose = 2)
    reduced_dim = applying_tsne.fit_transform(data)
    d = {'Dimension_1': applying_tsne.embedding_[:,0], 'Dimension_2': applying_tsne.embedding_[:,1], "activities":data_label}
    df = pd.DataFrame(data = d)
    print("Done...")
    print("Plotting TSNE Visualization...")
    sns.set_style('whitegrid') 
    sns.lmplot("Dimension_1", "Dimension_2", df, hue = 'activities', markers=['|','o','_', ">", "<", "^"], fit_reg = False, size = 10, scatter_kws={'s':100})
    plt.title("TSNE Plot for Perplexity "+str(perplexity))
    plt.show()

# %% [markdown]
# perplexities = [5, 10, 20, 40, 100]
# for perplexity in perplexities:
#     plt_tsne(perplexity, train_df)

# %%
perplexities = [5, 10, 20, 40, 100]
for perplexity in perplexities:
    plt_tsne(perplexity, train_df)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# [t-SNE] Computed neighbors for 7352 samples in 2.863s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.134s
# [t-SNE] Iteration 50: error = 114.1610413, gradient norm = 0.0220872 (50 iterations in 4.230s)
# [t-SNE] Iteration 100: error = 97.8650665, gradient norm = 0.0158020 (50 iterations in 2.945s)
# [t-SNE] Iteration 150: error = 93.3399887, gradient norm = 0.0092573 (50 iterations in 2.735s)
# [t-SNE] Iteration 200: error = 91.2954025, gradient norm = 0.0090649 (50 iterations in 3.216s)
# [t-SNE] Iteration 250: error = 90.0934830, gradient norm = 0.0048640 (50 iterations in 3.328s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.093483
# [t-SNE] Iteration 300: error = 3.5751092, gradient norm = 0.0014630 (50 iterations in 3.294s)
# [t-SNE] Iteration 350: error = 2.8164735, gradient norm = 0.0007537 (50 iterations in 3.233s)
# [t-SNE] Iteration 400: error = 2.4361207, gradient norm = 0.0005275 (50 iterations in 2.707s)
# [t-SNE] Iteration 450: error = 2.2183785, gradient norm = 0.0004043 (50 iterations in 2.756s)
# [t-SNE] Iteration 500: error = 2.0731354, gradient norm = 0.0003304 (50 iterations in 2.744s)
# [t-SNE] Iteration 550: error = 1.9674361, gradient norm = 0.0002826 (50 iterations in 2.520s)
# [t-SNE] Iteration 600: error = 1.8862770, gradient norm = 0.0002471 (50 iterations in 2.587s)
# [t-SNE] Iteration 650: error = 1.8211266, gradient norm = 0.0002192 (50 iterations in 2.923s)
# [t-SNE] Iteration 700: error = 1.7675874, gradient norm = 0.0001965 (50 iterations in 3.339s)
# [t-SNE] Iteration 750: error = 1.7223849, gradient norm = 0.0001790 (50 iterations in 3.300s)
# [t-SNE] Iteration 800: error = 1.6833979, gradient norm = 0.0001646 (50 iterations in 2.747s)
# [t-SNE] Iteration 850: error = 1.6495137, gradient norm = 0.0001546 (50 iterations in 2.534s)
# [t-SNE] Iteration 900: error = 1.6198775, gradient norm = 0.0001423 (50 iterations in 2.721s)
# [t-SNE] Iteration 950: error = 1.5933316, gradient norm = 0.0001339 (50 iterations in 2.776s)
# [t-SNE] Iteration 1000: error = 1.5694435, gradient norm = 0.0001249 (50 iterations in 2.937s)
# [t-SNE] KL divergence after 1000 iterations: 1.569443
# Done...
# Plotting TSNE Visualization...
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# [t-SNE] Computed neighbors for 7352 samples in 2.766s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.247s
# [t-SNE] Iteration 50: error = 105.8891296, gradient norm = 0.0205956 (50 iterations in 3.961s)
# [t-SNE] Iteration 100: error = 90.2871094, gradient norm = 0.0087261 (50 iterations in 3.192s)
# [t-SNE] Iteration 150: error = 87.2438812, gradient norm = 0.0056642 (50 iterations in 3.130s)
# [t-SNE] Iteration 200: error = 86.0122070, gradient norm = 0.0043248 (50 iterations in 3.424s)
# [t-SNE] Iteration 250: error = 85.3327637, gradient norm = 0.0030989 (50 iterations in 3.046s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.332764
# [t-SNE] Iteration 300: error = 3.1324990, gradient norm = 0.0013986 (50 iterations in 3.076s)
# [t-SNE] Iteration 350: error = 2.4874132, gradient norm = 0.0006474 (50 iterations in 2.649s)
# [t-SNE] Iteration 400: error = 2.1680436, gradient norm = 0.0004229 (50 iterations in 2.828s)
# [t-SNE] Iteration 450: error = 1.9838625, gradient norm = 0.0003128 (50 iterations in 3.271s)
# [t-SNE] Iteration 500: error = 1.8659352, gradient norm = 0.0002487 (50 iterations in 3.437s)
# [t-SNE] Iteration 550: error = 1.7827139, gradient norm = 0.0002106 (50 iterations in 3.090s)
# [t-SNE] Iteration 600: error = 1.7203245, gradient norm = 0.0001819 (50 iterations in 3.286s)
# [t-SNE] Iteration 650: error = 1.6714627, gradient norm = 0.0001593 (50 iterations in 3.204s)
# [t-SNE] Iteration 700: error = 1.6321510, gradient norm = 0.0001422 (50 iterations in 2.791s)
# [t-SNE] Iteration 750: error = 1.5999864, gradient norm = 0.0001285 (50 iterations in 3.266s)
# [t-SNE] Iteration 800: error = 1.5728420, gradient norm = 0.0001185 (50 iterations in 3.398s)
# [t-SNE] Iteration 850: error = 1.5495381, gradient norm = 0.0001098 (50 iterations in 3.408s)
# [t-SNE] Iteration 900: error = 1.5294127, gradient norm = 0.0001020 (50 iterations in 3.503s)
# [t-SNE] Iteration 950: error = 1.5119205, gradient norm = 0.0000960 (50 iterations in 3.545s)
# [t-SNE] Iteration 1000: error = 1.4965094, gradient norm = 0.0000920 (50 iterations in 3.444s)
# [t-SNE] KL divergence after 1000 iterations: 1.496509
# Done...
# Plotting TSNE Visualization...
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.002s...
# [t-SNE] Computed neighbors for 7352 samples in 2.870s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.405s
# [t-SNE] Iteration 50: error = 97.6333771, gradient norm = 0.0209407 (50 iterations in 4.783s)
# [t-SNE] Iteration 100: error = 83.9855118, gradient norm = 0.0062039 (50 iterations in 4.016s)
# [t-SNE] Iteration 150: error = 81.9196777, gradient norm = 0.0042167 (50 iterations in 3.702s)
# [t-SNE] Iteration 200: error = 81.1782074, gradient norm = 0.0033230 (50 iterations in 4.082s)
# [t-SNE] Iteration 250: error = 80.7853851, gradient norm = 0.0036259 (50 iterations in 3.997s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.785385
# [t-SNE] Iteration 300: error = 2.7053521, gradient norm = 0.0013071 (50 iterations in 3.881s)
# [t-SNE] Iteration 350: error = 2.1693485, gradient norm = 0.0005774 (50 iterations in 3.802s)
# [t-SNE] Iteration 400: error = 1.9184763, gradient norm = 0.0003489 (50 iterations in 3.836s)
# [t-SNE] Iteration 450: error = 1.7715778, gradient norm = 0.0002480 (50 iterations in 3.799s)
# [t-SNE] Iteration 500: error = 1.6771364, gradient norm = 0.0001924 (50 iterations in 3.794s)
# [t-SNE] Iteration 550: error = 1.6128745, gradient norm = 0.0001577 (50 iterations in 3.776s)
# [t-SNE] Iteration 600: error = 1.5662159, gradient norm = 0.0001345 (50 iterations in 3.821s)
# [t-SNE] Iteration 650: error = 1.5309442, gradient norm = 0.0001197 (50 iterations in 3.834s)
# [t-SNE] Iteration 700: error = 1.5041916, gradient norm = 0.0001045 (50 iterations in 3.844s)
# [t-SNE] Iteration 750: error = 1.4825449, gradient norm = 0.0000953 (50 iterations in 3.849s)
# [t-SNE] Iteration 800: error = 1.4648298, gradient norm = 0.0000925 (50 iterations in 3.883s)
# [t-SNE] Iteration 850: error = 1.4510763, gradient norm = 0.0000829 (50 iterations in 3.901s)
# [t-SNE] Iteration 900: error = 1.4394548, gradient norm = 0.0000799 (50 iterations in 3.881s)
# [t-SNE] Iteration 950: error = 1.4295547, gradient norm = 0.0000761 (50 iterations in 3.865s)
# [t-SNE] Iteration 1000: error = 1.4211599, gradient norm = 0.0000769 (50 iterations in 3.878s)
# [t-SNE] KL divergence after 1000 iterations: 1.421160
# Done...
# Plotting TSNE Visualization...
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# [t-SNE] Computed neighbors for 7352 samples in 2.939s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.399086
# [t-SNE] Computed conditional probabilities in 0.815s
# [t-SNE] Iteration 50: error = 87.4720764, gradient norm = 0.0335274 (50 iterations in 5.722s)
# [t-SNE] Iteration 100: error = 77.9066238, gradient norm = 0.0058070 (50 iterations in 5.310s)
# [t-SNE] Iteration 150: error = 76.5493240, gradient norm = 0.0029651 (50 iterations in 5.159s)
# [t-SNE] Iteration 200: error = 76.1137314, gradient norm = 0.0018107 (50 iterations in 5.148s)
# [t-SNE] Iteration 250: error = 75.8903198, gradient norm = 0.0013986 (50 iterations in 5.282s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.890320
# [t-SNE] Iteration 300: error = 2.2925282, gradient norm = 0.0012198 (50 iterations in 4.846s)
# [t-SNE] Iteration 350: error = 1.8631138, gradient norm = 0.0005125 (50 iterations in 4.626s)
# [t-SNE] Iteration 400: error = 1.6753849, gradient norm = 0.0002967 (50 iterations in 3.882s)
# [t-SNE] Iteration 450: error = 1.5696685, gradient norm = 0.0002025 (50 iterations in 4.107s)
# [t-SNE] Iteration 500: error = 1.5013095, gradient norm = 0.0001523 (50 iterations in 4.628s)
# [t-SNE] Iteration 550: error = 1.4541156, gradient norm = 0.0001232 (50 iterations in 4.404s)
# [t-SNE] Iteration 600: error = 1.4205596, gradient norm = 0.0001034 (50 iterations in 3.686s)
# [t-SNE] Iteration 650: error = 1.3963597, gradient norm = 0.0000923 (50 iterations in 3.954s)
# [t-SNE] Iteration 700: error = 1.3783127, gradient norm = 0.0000848 (50 iterations in 3.515s)
# [t-SNE] Iteration 750: error = 1.3642495, gradient norm = 0.0000758 (50 iterations in 4.705s)
# [t-SNE] Iteration 800: error = 1.3534498, gradient norm = 0.0000694 (50 iterations in 4.755s)
# [t-SNE] Iteration 850: error = 1.3445194, gradient norm = 0.0000660 (50 iterations in 4.777s)
# [t-SNE] Iteration 900: error = 1.3370560, gradient norm = 0.0000618 (50 iterations in 4.741s)
# [t-SNE] Iteration 950: error = 1.3311924, gradient norm = 0.0000622 (50 iterations in 4.744s)
# [t-SNE] Iteration 1000: error = 1.3267469, gradient norm = 0.0000598 (50 iterations in 4.717s)
# [t-SNE] KL divergence after 1000 iterations: 1.326747
# Done...
# Plotting TSNE Visualization...
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.001s...
# [t-SNE] Computed neighbors for 7352 samples in 3.289s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.559265
# [t-SNE] Computed conditional probabilities in 1.990s
# [t-SNE] Iteration 50: error = 76.8892822, gradient norm = 0.0337240 (50 iterations in 8.085s)
# [t-SNE] Iteration 100: error = 68.6024475, gradient norm = 0.0028901 (50 iterations in 6.858s)
# [t-SNE] Iteration 150: error = 68.0747604, gradient norm = 0.0017880 (50 iterations in 6.008s)
# [t-SNE] Iteration 200: error = 67.8847809, gradient norm = 0.0054847 (50 iterations in 6.263s)
# [t-SNE] Iteration 250: error = 67.7771530, gradient norm = 0.0009071 (50 iterations in 7.446s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.777153
# [t-SNE] Iteration 300: error = 1.7752404, gradient norm = 0.0011393 (50 iterations in 7.239s)
# [t-SNE] Iteration 350: error = 1.4681400, gradient norm = 0.0004234 (50 iterations in 6.966s)
# [t-SNE] Iteration 400: error = 1.3453448, gradient norm = 0.0002382 (50 iterations in 6.923s)
# [t-SNE] Iteration 450: error = 1.2806232, gradient norm = 0.0001559 (50 iterations in 6.918s)
# [t-SNE] Iteration 500: error = 1.2412499, gradient norm = 0.0001155 (50 iterations in 6.998s)
# [t-SNE] Iteration 550: error = 1.2144870, gradient norm = 0.0000895 (50 iterations in 6.976s)
# [t-SNE] Iteration 600: error = 1.1960062, gradient norm = 0.0000727 (50 iterations in 6.942s)
# [t-SNE] Iteration 650: error = 1.1827562, gradient norm = 0.0000625 (50 iterations in 6.992s)
# [t-SNE] Iteration 700: error = 1.1730355, gradient norm = 0.0000548 (50 iterations in 7.074s)
# [t-SNE] Iteration 750: error = 1.1658241, gradient norm = 0.0000508 (50 iterations in 6.800s)
# [t-SNE] Iteration 800: error = 1.1604918, gradient norm = 0.0000450 (50 iterations in 6.928s)
# [t-SNE] Iteration 850: error = 1.1563572, gradient norm = 0.0000434 (50 iterations in 6.957s)
# [t-SNE] Iteration 900: error = 1.1531268, gradient norm = 0.0000399 (50 iterations in 6.955s)
# [t-SNE] Iteration 950: error = 1.1506726, gradient norm = 0.0000383 (50 iterations in 7.019s)
# [t-SNE] Iteration 1000: error = 1.1486660, gradient norm = 0.0000369 (50 iterations in 6.948s)
# [t-SNE] KL divergence after 1000 iterations: 1.148666
# Done...
# Plotting TSNE Visualization...

# %% [markdown]
# <b>Observation</b><br>
# From above TSNE plots, we can observe that except <b>STANDING</b> and <b>SITTING</b>, all other activities are separated fairly well.

# %% [markdown]
# ## 8. Machine Learning Models

# %%
x_train = train_df.drop(["subject_id", "activity", "activity_name"], axis = 1)
y_train = train_df["activity"]

x_test = test_df.drop(["subject_id", "activity", "activity_name"], axis = 1)
y_test = test_df["activity"]

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((7352, 561), (7352,), (2947, 561), (2947,))

# %%
table = pd.DataFrame(columns = ["Model", "Accuracy(%)"])
def keeping_record(model_name, accuracy):
    global table
    table = table.append(pd.DataFrame([[model_name, accuracy]], columns = ["Model", "Accuracy(%)"]))
    table.reset_index(drop = True, inplace = True)

# %%
def print_confusionMatrix(Y_TestLabels, PredictedLabels):
    confusionMatx = confusion_matrix(Y_TestLabels, PredictedLabels)
    
    precision = confusionMatx/confusionMatx.sum(axis = 0)
    
    recall = (confusionMatx.T/confusionMatx.sum(axis = 1)).T
    
    sns.set(font_scale=1.5)
    
    # confusionMatx = [[1, 2],
    #                  [3, 4]]
    # confusionMatx.T = [[1, 3],
    #                   [2, 4]]
    # confusionMatx.sum(axis = 1)  axis=0 corresponds to columns and axis=1 corresponds to rows in two diamensional array
    # confusionMatx.sum(axix =1) = [[3, 7]]
    # (confusionMatx.T)/(confusionMatx.sum(axis=1)) = [[1/3, 3/7]
    #                                                  [2/3, 4/7]]

    # (confusionMatx.T)/(confusionMatx.sum(axis=1)).T = [[1/3, 2/3]
    #                                                    [3/7, 4/7]]
    # sum of row elements = 1
    
    labels = ["WALKING", "WALKING_UPSTAIRS", "WALKING_DOWNSTAIRS", "SITTING", "STANDING", "LYING"]
    
    plt.figure(figsize=(16,7))
    sns.heatmap(confusionMatx, cmap = "Blues", annot = True, fmt = ".1f", xticklabels=labels, yticklabels=labels)
    plt.title("Confusion Matrix", fontsize = 30)
    plt.xlabel('Predicted Class', fontsize = 20)
    plt.ylabel('Original Class', fontsize = 20)
    plt.tick_params(labelsize = 15)
    plt.xticks(rotation = 90)
    plt.show()
    
    print("-"*125)
    
    plt.figure(figsize=(16,7))
    sns.heatmap(precision, cmap = "Blues", annot = True, fmt = ".2f", xticklabels=labels, yticklabels=labels)
    plt.title("Precision Matrix", fontsize = 30)
    plt.xlabel('Predicted Class', fontsize = 20)
    plt.ylabel('Original Class', fontsize = 20)
    plt.tick_params(labelsize = 15)
    plt.xticks(rotation = 90)
    plt.show()
    
    print("-"*125)
    
    plt.figure(figsize=(16,7))
    sns.heatmap(recall, cmap = "Blues", annot = True, fmt = ".2f", xticklabels=labels, yticklabels=labels)
    plt.title("Recall Matrix", fontsize = 30)
    plt.xlabel('Predicted Class', fontsize = 20)
    plt.ylabel('Original Class', fontsize = 20)
    plt.tick_params(labelsize = 15)
    plt.xticks(rotation = 90)
    plt.show()

# %%
def apply_model(cross_val, x_train, y_train, x_test, y_test, model_name):
    start = datetime.now()
    cross_val.fit(x_train, y_train)
    predicted_points = cross_val.predict(x_test)
    
    print("Total time taken for tuning hyperparameter and making prediction by the model is (HH:MM:SS): {}\n".format(datetime.now() - start))
    accuracy = np.round(accuracy_score(y_test, predicted_points)*100, 2)
    
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print(str(accuracy)+"%\n")
    
    print('---------------------------')
    print('|      Best Estimator      |')
    print('---------------------------')
    print("{}\n".format(cross_val.best_estimator_))
    
    print('----------------------------------')
    print('|      Best Hyper-Parameters      |')
    print('----------------------------------')
    print(cross_val.best_params_)
    
    keeping_record(model_name, accuracy)
    
    print("\n\n")
    
    print_confusionMatrix(y_test, predicted_points)

# %% [markdown]
# ## 8.1 Logistic Regression

# %%
parameters = {"C": [0.001, 0.01, 0.1, 1, 10**1, 10**2, 10**3], "penalty": ["l1", "l2"]}
clf = LogisticRegression(multi_class = "ovr")
cross_val = GridSearchCV(clf, parameters, cv=3)
apply_model(cross_val, x_train, y_train, x_test, y_test, "Logistic Regression")
# Out:
# Total time taken for tuning hyperparameter and making prediction by the model is (HH:MM:SS): 0:01:04.594105
#
# ---------------------
# |      Accuracy      |
# ---------------------
# 96.13%
#
# ---------------------------
# |      Best Estimator      |
# ---------------------------
# LogisticRegression(C=100, multi_class='ovr')
#
# ----------------------------------
# |      Best Hyper-Parameters      |
# ----------------------------------
# {'C': 100, 'penalty': 'l2'}
# -----------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 8.2 Linear SVM

# %%
parameters = {"C": [0.001, 0.01, 0.1, 1, 10**1, 10**2, 10**3]}
clf = LinearSVC()
cross_val = GridSearchCV(clf, parameters, cv=3)
apply_model(cross_val, x_train, y_train, x_test, y_test, "Linear SVM")
# Out:
# Total time taken for tuning hyperparameter and making prediction by the model is (HH:MM:SS): 0:01:47.510039
#
# ---------------------
# |      Accuracy      |
# ---------------------
# 96.03%
#
# ---------------------------
# |      Best Estimator      |
# ---------------------------
# LinearSVC(C=10)
#
# ----------------------------------
# |      Best Hyper-Parameters      |
# ----------------------------------
# {'C': 10}
# -----------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 8.3 Decision Trees

# %%
parameters = {"max_depth": [2, 3, 4, 5, 6, 7, 8]}
clf = DecisionTreeClassifier()
cross_val = GridSearchCV(clf, parameters, cv=3)
apply_model(cross_val, x_train, y_train, x_test, y_test, "Decision Trees")
# Out:
# Total time taken for tuning hyperparameter and making prediction by the model is (HH:MM:SS): 0:00:59.271333
#
# ---------------------
# |      Accuracy      |
# ---------------------
# 85.48%
#
# ---------------------------
# |      Best Estimator      |
# ---------------------------
# DecisionTreeClassifier(max_depth=6)
#
# ----------------------------------
# |      Best Hyper-Parameters      |
# ----------------------------------
# {'max_depth': 6}
# -----------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 8.4 Random Forest

# %%
parameters = {"n_estimators": [50, 100, 200, 400, 800]}
clf = RandomForestClassifier()
cross_val = GridSearchCV(clf, parameters, cv=3)
apply_model(cross_val, x_train, y_train, x_test, y_test, "Random Forest")

# %% [markdown]
# ## 9. Model Comparison

# %%
ax = table.plot(x = "Model", y = "Accuracy(%)", kind = "bar", figsize = (14, 7), legend = False)
plt.title("Models Accuracy Score", fontsize = 20)
plt.xlabel("")
plt.margins(x = 0, y = 0.08)
plt.ylabel("Accuracy Score(%)", fontsize = 20)
plt.grid(visible = True)
for i in ax.patches:
    ax.text(x = i.get_x()+0.05, y = i.get_height()+1, s = str(i.get_height())+"%", fontsize = 16, color = "#232b2b")

# %%
table

# %% [markdown]
# <b>Comments</b><br>
# * Models: Logistic Regression and Linear SVM give accuracy above 96%.
# * In real world, having domain knowledge is one of the most important aspects of machine learning Modelling. Here, we got pretty good accuracy of above 96%. This is very much due to the fact that features are very well engineered by domain experts in signal processing.<br>
# * In a nutshell, feature engineering is one of the most important aspect of machine learning.
